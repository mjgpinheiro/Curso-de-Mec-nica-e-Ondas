# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Curso-de-Mec-nica-e-Ondas/blob/main/Haar_wavelet_T.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt

# Generate a simple signal
t = np.linspace(0, 1, 1024)
x = np.sin(2 * np.pi * 32 * t) + np.sin(2 * np.pi * 64 * t)

# Plot the signal
plt.plot(t, x)
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Apply the Haar wavelet transform
coeffs = pywt.dwt(x, 'haar')

# Plot the wavelet coefficients
plt.plot(coeffs[0])
plt.title('Approximation Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

plt.plot(coeffs[1])
plt.title('Detail Coefficients')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()
